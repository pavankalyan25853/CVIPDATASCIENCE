# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankalyan25853/CVIPDATASCIENCE/blob/main/EDA_Terorisam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import terrorism dataset
data=pd.read_csv("/content/globalterrorism.csv",sep=',', encoding='latin-1')
data
# Out:
# <ipython-input-10-1775547700d8>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("/content/globalterrorism.csv",sep=',', encoding='latin-1')
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       1.970000e+11   1970       7     2        NaN         0        NaN
# 1       1.970000e+11   1970       0     0        NaN         0        NaN
# 2       1.970010e+11   1970       1     0        NaN         0        NaN
# 3       1.970010e+11   1970       1     0        NaN         0        NaN
# 4       1.970010e+11   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 114486  2.013020e+11   2013       2    16        NaN         0        NaN
# 114487  2.013020e+11   2013       2    16        NaN         0        NaN
# ...

# %%
data.shape
# Out:
# (114491, 135)

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.shape
# Out:
# (114491, 135)

# %%
columns=list(data.columns)

# %%
data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                     'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                     'nwound': 'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                     'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)
# Out:
# <ipython-input-18-1b7c871a479e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',

# %%
data = data[['Year','Month','Day','Country','Region','state','city','latitude','longitude','AttackType','Killed','Wounded','Target',
            'Target','Summary','Group','Target_type','Weapon_type','Motive']]

# %%
data.shape
# Out:
# (114491, 21)

# %%
data.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# Region             0
# state            419
# city             434
# latitude        4140
# longitude       4141
# AttackType         0
# Killed          6773
# Wounded        10312
# Target           636
# Target           636
# Target           636
# Target           636
# Target           636
# Target           636
# Target           636
# Target           636
# Summary        66129
# Group              0
# Target_type        0
# Weapon_type        0
# Motive         74172
# dtype: int64

# %%
#Dropping all the null values and creating another dataframe
data2=data.dropna()

# %%
data2.shape
# Out:
# (37375, 33)

# %%
data2.isnull().sum()#To check for null values in new dataset
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# Region         0
# state          0
# city           0
# latitude       0
# longitude      0
# AttackType     0
# Killed         0
# Wounded        0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Summary        0
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         0
# dtype: int64

# %%
#Checking the data info
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37375 entries, 5 to 114476
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         37375 non-null  int64
#  1   Month        37375 non-null  int64
#  2   Day          37375 non-null  int64
#  3   Country      37375 non-null  object
#  4   Region       37375 non-null  object
#  5   state        37375 non-null  object
#  6   city         37375 non-null  object
#  7   latitude     37375 non-null  float64
#  8   longitude    37375 non-null  float64
#  9   AttackType   37375 non-null  object
#  10  Killed       37375 non-null  float64
#  11  Wounded      37375 non-null  float64
#  12  Target       37375 non-null  object
#  13  Target       37375 non-null  object
#  14  Target       37375 non-null  object
#  15  Target       37375 non-null  object
#  16  Target       37375 non-null  object
#  17  Target       37375 non-null  object
# ...

# %%
data2.head()
# Out:
#     Year  Month  Day        Country         Region        state         city  \
# 5   1970      1    1  United States  North America     Illinois        Cairo
# 8   1970      1    2  United States  North America    Wisconsin      Madison
# 9   1970      1    3  United States  North America    Wisconsin      Madison
# 11  1970      1    6  United States  North America     Colorado       Denver
# 14  1970      1    9  United States  North America  Puerto Rico  Rio Piedras
#
#      latitude   longitude                      AttackType  ...  \
# 5   37.005105  -89.176269                   Armed Assault  ...
# 8   43.076592  -89.412488  Facility/Infrastructure Attack  ...
# 9   43.072950  -89.386694  Facility/Infrastructure Attack  ...
# 11  39.758968 -104.876305  Facility/Infrastructure Attack  ...
# 14  18.386932  -66.061127  Facility/Infrastructure Attack  ...
#
#                                                Target  \
# 5                           Cairo Police Headquarters
# ...

# %%
#To check for null values in new dataset
data2.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# Region         0
# state          0
# city           0
# latitude       0
# longitude      0
# AttackType     0
# Killed         0
# Wounded        0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Target         0
# Summary        0
# Group          0
# Target_type    0
# Weapon_type    0
# Motive         0
# dtype: int64

# %%
#Finding Most attacked
print("Most attacked")
print('Country :',data2['Country'].value_counts().idxmax())
print('Year :',data2['Year'].value_counts().idxmax())
print('Month :',data2['Month'].value_counts().idxmax())
print('Region :',data2['Region'].value_counts().idxmax())
print('state :',data2['state'].value_counts().idxmax())
print('city :',data2['city'].value_counts().idxmax())
print('Group :',data2['Group'].value_counts().idxmax())
print('Weapon_type :',data2['Weapon_type'].value_counts().idxmax())
print('Motive :',data2['Motive'].value_counts().idxmax())
# Out:
# Most attacked
# Country : Iraq
# Year : 2011
# Month : 8
# Region : South Asia
# state : Baghdad
# city : Baghdad
# Group : Unknown
# Weapon_type : Explosives
# Motive : The specific motive for the attack is unknown.

# %%
print("Most attacked")
print('Country :',data2['Country'].value_counts().idxmin())
print('Year :',data2['Year'].value_counts().idxmin())
print('Month :',data2['Month'].value_counts().idxmin())
print('Region :',data2['Region'].value_counts().idxmin())
print('state :',data2['state'].value_counts().idxmin())
print('city :',data2['city'].value_counts().idxmin())
print('Group :',data2['Group'].value_counts().idxmin())
print('Weapon_type :',data2['Weapon_type'].value_counts().idxmin())
print('Motive :',data2['Motive'].value_counts().idxmin())
# Out:
# Most attacked
# Country : Uruguay
# Year : 1979
# Month : 12
# Region : Australasia & Oceania
# state : Haute-Kotto
# city : Lafayette
# Group : Core Conspirators for the Extension of Chaos (Núcleo de Conspiradores por la Extensión de Kaos)
# Weapon_type : Fake Weapons
# Motive : The specific motive for the attack was to intimidate the pro-government peace committee.

# %%
data2.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'state', 'city',
#        'latitude', 'longitude', 'AttackType', 'Killed', 'Wounded', 'Target',
#        'Target', 'Target', 'Target', 'Target', 'Target', 'Target', 'Target',
#        'Target', 'Target', 'Target', 'Target', 'Target', 'Target', 'Target',
#        'Target', 'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive'],
#       dtype='object')

# %%
# as we can see there are two Target named columns lets remove one
data2 = data2.loc[:, ~data2.columns.duplicated()]

# %%
data2.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'state', 'city',
#        'latitude', 'longitude', 'AttackType', 'Killed', 'Wounded', 'Target',
#        'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'state', 'city',
#        'latitude', 'longitude', 'AttackType', 'Killed', 'Wounded', 'Target',
#        'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive'],
#       dtype='object')

# %%
import plotly.express as px

# Group the data by country and count the number of attacks
country_counts = data2['Country'].value_counts().reset_index()
country_counts.columns = ['Country', 'Attack Count']

# Create the choropleth map
fig = px.choropleth(country_counts,
                    locations='Country',
                    locationmode='country names',
                    color='Attack Count',
                    title='Terrorist Attacks by Country',
                    labels={'Attack Count': 'Number of Attacks'},
                    hover_name='Country',
                    color_continuous_scale='reds')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data2['Year'],y=data2['Killed'])
plt.show()

# %%
import plotly.graph_objects as go
# Group the data by terrorist group and count the number of attacks
group_counts = data2['Group'].value_counts().reset_index()
group_counts.columns = ['Group', 'Attack Count']

# Create the sunburst chart
fig = go.Figure(go.Sunburst(
    labels=group_counts['Group'],
    parents=["" for _ in group_counts['Group']],
    values=group_counts['Attack Count']
))

fig.update_layout(
    title='Terrorist Attacks by Group',
    hovermode='closest'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
